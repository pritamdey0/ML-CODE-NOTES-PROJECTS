# %%
import pandas as pd
c=type(pd.read_csv('first.py'))
print(c)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import numpy as np
import pandas as pd

# %%
# string
country = ['India','Pakistan','USA','Nepal','Srilanka']

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: object

# %%
# integers
runs = [13,24,56,78,100]

runs_ser = pd.Series(runs)
runs_ser
# Out:
# 0     13
# 1     24
# 2     56
# 3     78
# 4    100
# dtype: int64

# %%
# custom index
marks = [67,57,89,100]
subjects = ['maths','english','science','hindi']

pd.Series(marks,index=subjects)
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# dtype: int64

# %%
# setting a name
marks = pd.Series(marks,index=subjects,name='Nitish ke marks')
marks
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: Nitish ke marks, dtype: int64

# %% [markdown]
# SERIES FROM DICT

# %%
marks = {
    'maths':67,
    'english':57,
    'science':89,
    'hindi':100
}

marks_series = pd.Series(marks,name='nitish ke marks')
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %% [markdown]
# SERIES ATTRIBUTES

# %%
# size
marks_series.size
# Out:
# 4

# %%
# dtype
marks_series.dtype
# Out:
# dtype('int64')

# %%
# name
marks_series.name
# Out:
# 'nitish ke marks'

# %%
# is_unique
marks_series.is_unique

pd.Series([1,1,2,3,4,5]).is_unique
# Out:
# False

# %%
# index
marks_series.index
# Out:
# Index(['maths', 'english', 'science', 'hindi'], dtype='object')

# %%
runs_ser.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# values
marks_series.values
# Out:
# array([ 67,  57,  89, 100])

# %% [markdown]
# **SERIES USING READ_CSV**

# %%
import pandas as pd
subs=pd.read_csv('/content/subs.csv').squeeze("columns")
subs
# print(subs)
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
pd.read_csv('/content/bollywood.csv').squeeze("columns")
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
# with 2 cols
pd.read_csv('/content/kohli_ipl.csv', index_col='match_no').squeeze("columns")
vk = pd.read_csv('/content/kohli_ipl.csv', index_col='match_no').squeeze("columns")
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv('/content/movies.csv',index_col='movie').squeeze("columns")
movies
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2939/3470938439.py in <cell line: 0>()
# ----> 1 movies = pd.read_csv('/content/movies.csv',index_col='movie').squeeze("columns")
#       2 movies
#
# ...

# %% [markdown]
# #Important Series Methods

# %%
#Head and Tail functions

import pandas as pd

subs = pd.read_csv('/content/subs.csv').squeeze("columns")
# subs.head()
# subs.head(2)   #Top 5 records
subs.tail(3)   # Below top 5 record , can give parameters as well
# Out:
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, dtype: int64

# %%
#Sample Values
# subs.sample() # gives 1 random row from data
subs.sample(5)  #can give parameter
# Out:
# 101    72
# 75     70
# 42     33
# 78     98
# 99     87
# Name: Subscribers gained, dtype: int64

# %%
#Value_counts -> movies => frequency of every value

pd.read_csv('/content/bollywood.csv').squeeze("columns")
movies = pd.read_csv('/content/bollywood.csv',index_col='movie').squeeze("columns")
movies
movies.value_counts()
# Out:
# lead
# Akshay Kumar         48
# Amitabh Bachchan     45
# Ajay Devgn           38
# Salman Khan          31
# Sanjay Dutt          26
#                      ..
# Seema Azmi            1
# Akanksha Puri         1
# Charanpreet Insan     1
# Jaideep Ahlawat       1
# Monali Thakur         1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values ->inplace
vk = pd.read_csv('/content/drive/MyDrive/kohli_ipl.csv', index_col='match_no').squeeze("columns")
vk
# vk.sort_values()
# vk.sort_values(ascending=False)
# c
c=vk.sort_values(ascending=False).head(1)
# vk.sort_values(ascending=False).head(1).values
# vk.sort_values(ascending=False).head(1).values[0]
# above all are examples of method chaining
# vk
c
# Out:
# match_no
# 128    113
# Name: runs, dtype: int64

# %%
vk
#Sort values does temporarirly changes not permanent
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
c.sort_values(inplace=True)
c # does permanent changes
# vk
# Out:
# match_no
# 128    113
# Name: runs, dtype: int64

# %%
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# sort_index ->movies (index sorting is done)
# movies
# movies.sort_index()
# movies.sort_index(inplace=True)
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# #Series MAths Methods

# %%
#count
vk.count() #it will not count missing values
# vk
vk.sum()
# Out:
# np.int64(6634)

# %%
# sum and product
vk.sum()
# Out:
# np.int64(6634)

# %%
# subs.product()
 #product
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6038/169265218.py in <cell line: 0>()
# ----> 1 subs.product() #product
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in prod(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11680         **kwargs,
#   11681     ):
# > 11682         result = super().prod(axis, skipna, numeric_only, min_count, **kwargs)
#   11683         return result.__finalize__(self, method="prod")
#   11684
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in prod(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12516         **kwargs,
#   12517     ):
# > 12518         return self._min_count_stat_function(
#   12519             "prod",
#   12520             nanops.nanprod,
#
# ...

# %%
# mean ,median,mode, std,var
vk.mean()
# subs.median()
vk.median()
vk.mode()
# print(movies.mode())  # frequent item used in the data
# print(subs.std())
# print(vk.var())
# Out:
# 0    0
# Name: runs, dtype: int64

# %%
#min/max
subs.min()
# Out:
# movie    1920 (film)
# lead      Aadar Jain
# dtype: object

# %%
subs.max()
# Out:
# movie    Zor Lagaa Ke...Haiya!
# lead               Zulfi Sayed
# dtype: object

# %%
# describe - gives all mathematical values
vk.describe()
# Out:
# count    215.000000
# mean      30.855814
# std       26.229801
# min        0.000000
# 25%        9.000000
# 50%       24.000000
# 75%       48.000000
# max      113.000000
# Name: runs, dtype: float64

# %% [markdown]
# #Series Indexing

# %%
# integer indexing
x = pd.Series([12,13,14,35,46,58,78,9])
x[1]
# x[-3]
#  Sereis doesnt work on negative numbers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     412             try:
# --> 413                 return self._range.index(new_key)
#     414             except ValueError as err:
#
# ValueError: -3 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_6631/2672788480.py in <cell line: 0>()
#       2 x = pd.Series([12,13,14,35,46,58,78,9])
#       3 x[1]
# ----> 4 x[-3]
#       5 #  Sereis doesnt work on negative numbers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
# ...

# %%
#ILOC
# This gets the second row of the DataFrame/Series by its position
vk.iloc[2]
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
vk.iloc[-1]
# Out:
# np.int64(7)

# %% [markdown]
# # SLICING

# %%
vk[5:16]
vk #between 5 and 16 matches
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2939/1318797195.py in <cell line: 0>()
# ----> 1 vk[5:16]
#       2 vk #between 5 and 16 matches
#
# NameError: name 'vk' is not defined

# %%
#negative slicing
vk[-5:]
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
movies[-5:]
# Out:
# movie
# Hum Tumhare Hain Sanam      Shah Rukh Khan
# Aankhen (2002 film)       Amitabh Bachchan
# Saathiya (film)               Vivek Oberoi
# Company (film)                  Ajay Devgn
# Awara Paagal Deewana          Akshay Kumar
# Name: lead, dtype: object

# %%
movies[::2]
# movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# The Accidental Prime Minister (film)         Anupam Kher
# Evening Shadows                         Mona Ambegaonkar
# Fraud Saiyaan                               Arshad Warsi
# Manikarnika: The Queen of Jhansi          Kangana Ranaut
#                                               ...
# Raaz (2002 film)                              Dino Morea
# Waisa Bhi Hota Hai Part II                  Arshad Warsi
# Kaante                                  Amitabh Bachchan
# Aankhen (2002 film)                     Amitabh Bachchan
# Company (film)                                Ajay Devgn
# Name: lead, Length: 750, dtype: object

# %%
#Fancy Indexing
vk[[2]] #whatever row value we want
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
#indexing with labels -> fancy indexing
# Use .loc for row labels
movies.loc['2 States (2014 film)']
# Out:
# 'Arjun Kapoor'

# %% [markdown]
# # EDITING ITEMS IN SERIES

# %%
#using indexing

marks_series[1]=100
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %%
# what if an index does not exist
marks_series['sst']=90
marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# sst         90
# Name: nitish ke marks, dtype: int64

# %%
#same can be done with labels
# movies['2 states (2024 film)']='Alia Bhatt'
movies['Uri: The Surgical Strike']='Yami Gautam'
movies
# Out:
# movie
# Uri: The Surgical Strike                     Yami Gautam
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # SERIES WITH PYTHON FUNCTIONALITIES

# %%
# len/type/dir/sorted/max/min

# %%
# print(len(subs))
# print(type(subs))
# print(dir(subs))
# print(sorted(subs)) #ascending to descending order in alist
# print(min(subs))
# print(max(subs))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__r
# ...

# %%
# type conversion
marks_series
list(marks_series)
# Out:
# [67, 57, 89, 100]

# %%
dict(marks_series)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6038/1412950007.py in <cell line: 0>()
# ----> 1 dict(marks_series)
#
# NameError: name 'marks_series' is not defined

# %%
#membership operator  - works only on indexes not values
# movies
# '2 States (2014 film)' in movies
'Darsheel Safari' in movies
# 'Alia Bhatt' in movies.values
# Out:
# False

# %%
# looping
for i in movies.index:
    print(i)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
#Arithmetic Operators (Broadcasting example)
marks_series
# 100 - marks_series
# 50 + marks_series
# Out:
# maths       67
# english     57
# science     89
# hindi      100
# Name: nitish ke marks, dtype: int64

# %%
# Relations Operators
vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# # BOOLEAN INDEXING

# %%
# Find no of 50's and 100's scored by kohli
vk>=50
vk[vk>=50]
vk[vk>=50].size
# Out:
# 50

# %%
# find number of ducks
vk == 0
vk[vk ==0]
vk[vk ==0].size
# Out:
# 9

# %%
# Count number of day when I had more than 200 subs a day
subs > 200
subs[subs > 200]
subs[subs>200].size
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6038/4113488662.py in <cell line: 0>()
#       1 # Count number of day when I had more than 200 subs a day
# ----> 2 subs > 200
#       3 subs[subs > 200]
#       4 subs[subs>200].size
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      74         other = item_from_zerodim(other)
#      75
# ---> 76         return method(self, other)
#      77
#      78     return new_method
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arraylike.py in __gt__(self, other)
#      54     @unpack_zerodim_and_defer("__gt__")
#      55     def __gt__(self, other):
# ---> 56         return self._cmp_method(other, operator.gt)
#      57
#      58     @unpack_zerodim_and_defer("__ge__")
#
# ...

# %%
subs
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
# find actors who have done more than 20 movies
num_movies= movies.value_counts()
num_movies > 20
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Emraan Hashmi       21
# Name: count, dtype: int64

# %% [markdown]
# # PLOTTING GRAPHS ON SERIES

# %%
subs.plot(movies,lead) # convert subs no into 2d plot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6038/2251596446.py in <cell line: 0>()
# ----> 1 subs.plot(movies,lead) # convert subs no into 2d plot
#
# NameError: name 'lead' is not defined

# %% [markdown]
# **DATAFRAMES **

# %%
# 2D form of Data is dataframe . Means rows and columns of tables are dataframes .

# %%
import numpy as np
import pandas as pd

# %%
#using list

student_data = [
    [100,80,10],[90,70,7],[120,100,14],[80,50,2]
]
pd.DataFrame(student_data,columns=['iq','marks','package'])
# Out:
#     iq  marks  package
# 0  100     80       10
# 1   90     70        7
# 2  120    100       14
# 3   80     50        2

# %%
#using dicts
student_dict = {
    'name':['nitish','ankit','rupesh','rishabh','akhil','raj'],
    'iq':[100,90,120,80,0,0],
    'marks':[80,70,100,50,0,0],
    'package':[10,7,14,2,0,0]
}
pd.DataFrame(student_dict)
students = pd.DataFrame(student_dict)
students.set_index('name',inplace=True)

students
# Out:
#           iq  marks  package
# name
# nitish   100     80       10
# ankit     90     70        7
# rupesh   120    100       14
# rishabh   80     50        2
# akhil      0      0        0
# raj        0      0        0

# %%
# using read_csv
pd.read_csv('/content/bollywood.csv')
movies = pd.read_csv('/content/bollywood.csv')
movies
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
pd.read_csv('/content/kohli_ipl.csv')
ipl= pd.read_csv('/content/kohli_ipl.csv')
ipl
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]

# %% [markdown]
# **DATAFRAMES ATTRIBUTES AND METHODS**

# %%
# shape - tells rows and columns
# movies.shape
ipl.shape
# Out:
# (215, 2)

# %%
#dtypes - object is equal to string in pandas
# movies.dtypes
ipl.dtypes
# movies
# Out:
# match_no    int64
# runs        int64
# dtype: object

# %%
#index
movies.index
# ipl.index
# movies
# Out:
# RangeIndex(start=0, stop=1500, step=1)

# %%
# columns
movies.columns
# ipl.columns
# student.columns
# Out:
# Index(['movie', 'lead'], dtype='object')

# %%
# Values - gives entire data into 2D numpy array
movies.values
# ipl.values
# Out:
# array([['Uri: The Surgical Strike', 'Vicky Kaushal'],
#        ['Battalion 609', 'Vicky Ahuja'],
#        ['The Accidental Prime Minister (film)', 'Anupam Kher'],
#        ...,
#        ['Saathiya (film)', 'Vivek Oberoi'],
#        ['Company (film)', 'Ajay Devgn'],
#        ['Awara Paagal Deewana', 'Akshay Kumar']], dtype=object)

# %%
# head and tail
movies
movies.head()
movies.head(2)
movies.tail()
movies.tail(7)
# Out:
#                          movie              lead
# 1493  Devdas (2002 Hindi film)    Shah Rukh Khan
# 1494                    Kaante  Amitabh Bachchan
# 1495    Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496       Aankhen (2002 film)  Amitabh Bachchan
# 1497           Saathiya (film)      Vivek Oberoi
# 1498            Company (film)        Ajay Devgn
# 1499      Awara Paagal Deewana      Akshay Kumar

# %%
#Sample - random data generated
movies.sample(5)
# Out:
#                        movie           lead
# 1198         Rang De Basanti     Aamir Khan
# 1253      Dreams (2006 film)     Aseel Adel
# 1296           Revati (film)  Kashmira Shah
# 824      Striker (2010 film)      Siddharth
# 798   Mere Brother Ki Dulhan     Imran Khan

# %%
#info
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   movie   1500 non-null   object
#  1   lead    1500 non-null   object
# dtypes: object(2)
# memory usage: 23.6+ KB

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   match_no  215 non-null    int64
#  1   runs      215 non-null    int64
# dtypes: int64(2)
# memory usage: 3.5 KB

# %%
# describe
movies.describe()
# Out:
#                           movie          lead
# count                      1500          1500
# unique                     1497           566
# top     Tanu Weds Manu: Returns  Akshay Kumar
# freq                          2            48

# %%
ipl.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
#isnull - returns boolean values
# movies.isnull()
movies.isnull().sum()
 # return the total sum of True values(1) of missing values
# Out:
# movie    0
# lead     0
# dtype: int64

# %%
# duplicated
# movies.duplicated()
# movies.duplicated().sum()
movies.duplicated().sum()
movies[movies.duplicated()]
# movies # returns sum of duplicated values
# Out:
#                         movie            lead
# 358   Tanu Weds Manu: Returns  Kangana Ranaut
# 368            Gabbar Is Back    Akshay Kumar
# 1418                   Andaaz    Akshay Kumar

# %%
# Add 0 values in students and then run
students.duplicated().sum()
# Out:
# np.int64(1)

# %%
# rename
# students.rename(columns={'marks':'percent','package':'lpa'}) # temporarily
# students.rename(columns={'marks':'percent','package':'lpa'},inplace=True) # permanently
students
# Out:
#           iq  marks  package
# name
# nitish   100     80       10
# ankit     90     70        7
# rupesh   120    100       14
# rishabh   80     50        2
# akhil      0      0        0
# raj        0      0        0

# %% [markdown]
# **MATH METHODS**

# %%
#sum  -> axis argument
students.sum()
students.sum(axis=1)
# Out:
# 0    190
# 1    167
# 2    234
# 3    132
# 4      0
# 5      0
# dtype: int64

# %%
students.mean(axis=1)
# Out:
# 0    63.333333
# 1    55.666667
# 2    78.000000
# 3    44.000000
# 4     0.000000
# 5     0.000000
# dtype: float64

# %%
students.median(axis=1)
# Out:
# 0     80.0
# 1     70.0
# 2    100.0
# 3     50.0
# 4      0.0
# 5      0.0
# dtype: float64

# %%
students.var(axis=1)
# Out:
# 0    2233.333333
# 1    1876.333333
# 2    3172.000000
# 3    1548.000000
# 4       0.000000
# 5       0.000000
# dtype: float64

# %%
students.std(axis=1)
# Out:
# 0    47.258156
# 1    43.316663
# 2    56.320511
# 3    39.344631
# 4     0.000000
# 5     0.000000
# dtype: float64

# %% [markdown]
# **Selecting columns from a Dataframe**

# %%
# single cols
movies['lead']
type(movies['lead'])
# movies
# Out:
# pandas.core.series.Series

# %%
ipl['runs'] # display data in form of series
# Out:
# 0       1
# 1      23
# 2      13
# 3      12
# 4       1
#        ..
# 210     0
# 211    20
# 212    73
# 213    25
# 214     7
# Name: runs, Length: 215, dtype: int64

# %%
# Multiple columns - If multile col then it is dataframe and only one is Sereis
movies[['movie','lead']]  # only 3 cols displayed
type(movies[['movie','lead']] )
# Out:
# pandas.core.frame.DataFrame

# %%
ipl[['Team1','Team2','WinningTeam']]
# Out:
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# 3               Rajasthan Royals               Gujarat Titans
# 4            Sunrisers Hyderabad                 Punjab Kings
# ..                           ...                          ...
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                      WinningTeam
# 0                 Gujarat Titans
# 1               Rajasthan Royals
# 2    Royal Challengers Bangalore
# 3                 Gujarat Titans
# 4                   Punjab Kings
# ...

# %%
# Add new names in studnet_dict

# %% [markdown]
# **Selecting Rows from a dataframe**
#
#
# *   iloc - searches using index positions
# *   loc - searches using index labels

# %%
#single row
# movies.iloc[3]
# movies.loc['Ajay Devgn']
movies
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
#multiple row
movies.iloc[0:5]
# movies.iloc[5:16]
# Out:
#                                   movie              lead
# 0              Uri: The Surgical Strike     Vicky Kaushal
# 1                         Battalion 609       Vicky Ahuja
# 2  The Accidental Prime Minister (film)       Anupam Kher
# 3                       Why Cheat India     Emraan Hashmi
# 4                       Evening Shadows  Mona Ambegaonkar

# %%
# fancy indexing
movies.iloc[[0,4,5]]
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 4           Evening Shadows  tt6028796
# 5               Soni (film)  tt6078866
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 5          https://en.wikipedia.org/wiki/Soni_(film)
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 4           Evening Shadows           Evening Shadows         0
# 5                      Soni                      Soni         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# ...

# %%
#loc

students
# Out:
#           iq  marks  package
# name
# nitish   100     80       10
# ankit     90     70        7
# rupesh   120    100       14
# rishabh   80     50        2
# akhil      0      0        0
# raj        0      0        0

# %%
students.loc['rupesh']
# Out:
# iq         120
# marks      100
# package     14
# Name: rupesh, dtype: int64

# %%
students.loc['rupesh':'raj':2]
# Out:
#          iq  marks  package
# name
# rupesh  120    100       14
# akhil     0      0        0

# %%
students.iloc[0:5:2] #want to fetch from label from rows, default iloc otherwise loc
# Out:
#          iq  marks  package
# name
# nitish  100     80       10
# rupesh  120    100       14
# akhil     0      0        0

# %%
# Selecting both rows and columns
# if only 3 columns for frist 3 movies
movies.iloc[0:3,0:3]           # input is index position (internal indexing)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.loc[0:2,'title_x':'poster_path'] #provide the name of rows (external indexing)
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# **Filtering the dataframe**

# %%
ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
# 3 find all the final winners
mask = ipl["MatchNumber"]=='Final'
ipl[mask]
new_df = ipl[mask]
new_df[['Season','WinningTeam']]

# ipl[ipl['MatchNumber'] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
# how many super over finishes have occured
ipl['SuperOver']=='Y'
ipl[ipl['SuperOver']=='Y']
ipl[ipl['SuperOver']=='Y'].shape[0]
# Out:
# 14

# %%
# how many matches has csk has won in kolkata
ipl[ipl['City']=='Kolkata']
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')]
ipl[(ipl['City']=='Kolkata') & (ipl['WinningTeam']=='Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
# toss winner is match winner in percentage
ipl['TossWinner'] == ipl['WinningTeam']
ipl[ipl['TossWinner'] == ipl['WinningTeam']]
(ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0] / ipl.shape[0])*100
# Out:
# 51.473684210526315

# %%
# movies with rating higher than 8 and votes>10000
# (movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)
movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
# Action movies with rating higher than 7.5
movies.sample(2)
movies['genres'].str.split('|')
movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask1 = movies['genres'].str.split('|').apply(lambda x:'Action' in x)
mask2= movies['imdb_rating']>7.5
movies[mask1 & mask2]
# Out:
#                             title_x    imdb_id  \
# 0          Uri: The Surgical Strike  tt8291224
# 41             Family of Thakurganj  tt8897986
# 84                        Mukkabaaz  tt7180544
# 106                           Raazi  tt7098658
# 110   Parmanu: The Story of Pokhran  tt6826438
# 112         Bhavesh Joshi Superhero  tt6129302
# 169                The Ghazi Attack  tt6299040
# 219                Raag Desh (film)  tt6080746
# 258                   Irudhi Suttru  tt5310090
# 280                       Laal Rang  tt5600714
# 297                     Udta Punjab  tt4434004
# 354                   Dangal (film)  tt5074352
# 362               Bajrangi Bhaijaan  tt3863552
# 365          Baby (2015 Hindi film)  tt3848892
# 393      Detective Byomkesh Bakshy!  tt3447364
# 449               Titli (2014 film)  tt3019620
# 536                   Haider (film)  tt3390572
# 589                    Vishwaroopam  tt2199711
# 625                     Madras Cafe  tt2855648
# ...

# %%
# How to add new columns
movies['Country']='India'
movies.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
# from exosting ones
# movies.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6038/652111864.py in <cell line: 0>()
#       1 # from exosting ones
# ----> 2 movies['actors'].str.split('|').apply(lambda x:x[0])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...

# %%
# astype
ipl.info()
ipl['ID'] = ipl['ID'].astype('int32') # reducing the size of column data
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Season']=ipl['Season'].astype('category')
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# **Important Series Method **

# %%
# astype
import sys
sys.getsizeof(vk) # gives total size of series
# Out:
# 3472

# %%
sys.getsizeof(vk.astype('int16'))
# Out:
# 2182

# %%
#between
vk.between(51,99)
vk[vk.between(51,99)].size
# Out:
# 43

# %%
#Clip
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
#drop_duplicates
temp = pd.Series([1,1,2,2,3,3,4,4]) #first occurence is kept and rest is dropped
temp
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 1    1
# 3    2
# 5    3
# 7    4
# dtype: int64

# %%
# movies.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2939/309552964.py in <cell line: 0>()
# ----> 1 movies.drop_duplicates()
#
# NameError: name 'movies' is not defined

# %%
#duplicated
temp.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# dtype: bool

# %%
#isnull
vk.isnull()
vk.isnull().sum()
# Out:
# np.int64(0)

# %%
temp.isnull().sum()
# Out:
# np.int64(0)

# %%
#dropna
temp.dropna()
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
#fillna
temp.fillna(0)
temp.fillna(temp.mean())
# Out:
# 0    1
# 1    1
# 2    2
# 3    2
# 4    3
# 5    3
# 6    4
# 7    4
# dtype: int64

# %%
#isin - check multiple conditions

(vk == 49) | (vk ==99)
vk[(vk == 49) | (vk ==99)]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
vk.isin([49,99])
vk[vk.isin([49,99])]
# Out:
# match_no
# 82    99
# 86    49
# Name: runs, dtype: int64

# %%
#apply
movies.apply(lambda x:x.split()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2939/2228807399.py in <cell line: 0>()
#       1 #apply
# ----> 2 movies.apply(lambda x:x.split()[0])
#
# NameError: name 'movies' is not defined

# %%
subs
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
subs.apply(lambda x:'good day' if x>subs.mean() else 'bad day')
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: object

# %%
#copy
vk
# vk.head()
# new=vk.head()
# new
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
new[1]=1 # if you are changing head or tail then original value gets changed

# %%
new = vk.head().copy()
new[1]=100
new
# Out:
# match_no
# 1    100
# 2     23
# 3     13
# 4     12
# 5      1
# Name: runs, dtype: int64
