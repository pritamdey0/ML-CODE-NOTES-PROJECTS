# %% [markdown]
# ## Why Seaborn?
#
#
# 1.   provides a layer of abstraction hence simpler to use
#
# 2.   better aesthetics and more graphs included

# %% [markdown]
# # **Seaborn Roadmap**
# Types of Functions
#
# Figure Level
# Axis Level
# Main Classification
#
# Relational Plot
# Distribution Plot
# Categorical Plot
# Regression Plot
# Matrix Plot
# Multiplots
# https://seaborn.pydata.org/api.html

# %% [markdown]
# # **1. Relational Plot**
# -> to see the statistical relation between 2 or more variables.
#
# -> Bivariate Analysis
#
# Plots under this section
#
# *   scatterplot
# *   lineplot

# %%
#Scatter Plot
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# scatter plot -> axes level function
sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex',style='time',size='size')
# sns.scatterplot(data=tips, x='total_bill', y='tip',hue='sex',style='time',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
#above as same function
# relplot -> figure level -> square shape
#Hue changes the color of parameter , automatically adds the legend
#Style differenctiaties the values
# sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter')
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',hue='sex',style='time',size='size')

# %%
# line plot
# Data set ->  gapminder which contains country's data with different life data
# Find india dataset with all the columns , then life expectency

gap = px.data.gapminder()
gap
# gap[gap['country'] == 'China']
temp_df = gap[gap['country'] == 'Japan']
temp_df
# gap['country'].isin(['India','Brazil','China'])
# Out:
#     country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 792   Japan      Asia  1952   63.030   86459025   3216.956347       JPN
# 793   Japan      Asia  1957   65.500   91563009   4317.694365       JPN
# 794   Japan      Asia  1962   68.730   95831757   6576.649461       JPN
# 795   Japan      Asia  1967   71.430  100825279   9847.788607       JPN
# 796   Japan      Asia  1972   73.420  107188273  14778.786360       JPN
# 797   Japan      Asia  1977   75.380  113872473  16610.377010       JPN
# 798   Japan      Asia  1982   77.110  118454974  19384.105710       JPN
# 799   Japan      Asia  1987   78.670  122091325  22375.941890       JPN
# 800   Japan      Asia  1992   79.360  124329269  26824.895110       JPN
# 801   Japan      Asia  1997   80.690  125956499  28816.584990       JPN
# 802   Japan      Asia  2002   82.000  127065841  28604.591900       JPN
# 803   Japan      Asia  2007   82.603  127467972  31656.068060       JPN
#
#      iso_num
# 792      392
# 793      392
# 794      392
# 795      392
# 796      392
# 797      392
# 798      392
# 799      392
# 800      392
# 801      392
# 802      392
# 803      392

# %%
# axes level function
# India's Life expectency over the years
sns.lineplot(data=temp_df, x='year', y='lifeExp')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# using relpplot
# same graph with relplot
sns.relplot(data=temp_df, x='year', y='lifeExp', kind='line')

# %%
# hue -> style
#

temp_df= gap[gap['country'].isin(['India','Brazil','China'])]
temp_df

# temp_df = gap[gap['country'].isin(['India','Brazil','Germany'])]
# temp_df
# Out:
#     country continent  year   lifeExp         pop    gdpPercap iso_alpha  \
# 168  Brazil  Americas  1952  50.91700    56602560  2108.944355       BRA
# 169  Brazil  Americas  1957  53.28500    65551171  2487.365989       BRA
# 170  Brazil  Americas  1962  55.66500    76039390  3336.585802       BRA
# 171  Brazil  Americas  1967  57.63200    88049823  3429.864357       BRA
# 172  Brazil  Americas  1972  59.50400   100840058  4985.711467       BRA
# 173  Brazil  Americas  1977  61.48900   114313951  6660.118654       BRA
# 174  Brazil  Americas  1982  63.33600   128962939  7030.835878       BRA
# 175  Brazil  Americas  1987  65.20500   142938076  7807.095818       BRA
# 176  Brazil  Americas  1992  67.05700   155975974  6950.283021       BRA
# 177  Brazil  Americas  1997  69.38800   168546719  7957.980824       BRA
# 178  Brazil  Americas  2002  71.00600   179914212  8131.212843       BRA
# 179  Brazil  Americas  2007  72.39000   190010647  9065.800825       BRA
# 288   China      Asia  1952  44.00000   556263527   400.448611       CHN
# 289   China      Asia  1957  50.54896   637408000   575.987001       CHN
# 290   China      Asia  1962  44.50136   665770000   487.674018       CHN
# 291   China      Asia  1967  58.38112   754550000   612.705693       CHN
# 292   China      Asia  1972  63.11888   862030000   676.900092       CHN
# 293   China      Asia  1977  63.96736   943455000   741.237470       CHN
# 294   China      Asia  1982  65.52500  1000281000   962.421381       CHN
# 295   China      Asia  1987  67.27400  1084035000  1378.904018       CHN
# 296   China      Asia  1992  68.69000  1164970000  1655.784158       CHN
# 297   China      Asia  1997  70.42600  1230075000  2289.234136       CHN
# 298   China      Asia  2002  72.02800  1280400000  3119.280896       CHN
# 299   China      Asia  2007  72.96100  1318683096  4959.114854       CHN
# 696   India      Asia  1952  37.37300   372000000   546.565749       IND
# 697   India      Asia  1957  40.24900   409000000   590.061996       IND
# 698   India      Asia  1962  43.60500   454000000   658.347151       IND
# 699   India      Asia  1967  47.19300   506000000   700.770611       IND
# 700   India      Asia  1972  50.65100   567000000   724.032527       IND
# 701   India      Asia  1977  54.20800   634000000   813.337323       IND
# 702   India      Asia  1982  56.59600   708000000   855.723538       IND
# 703   India      Asia  1987  58.55300   788000000   976.512676       IND
# 704   India      Asia  1992  60.22300   872000000  1164.406809       IND
# 705   India      Asia  1997  61.76500   959000000  1458.817442       IND
# 706   India      Asia  2002  62.87900  1034172547  1746.769454       IND
# 707   India      Asia  2007  64.69800  1110396331  2452.210407       IND
#
#      iso_num
# 168       76
# 169       76
# 170       76
# 171       76
# 172       76
# 173       76
# 174       76
# 175       76
# 176       76
# 177       76
# 178       76
# 179       76
# 288      156
# 289      156
# 290      156
# 291      156
# 292      156
# 293      156
# 294      156
# 295      156
# 296      156
# 297      156
# 298      156
# 299      156
# 696      356
# 697      356
# 698      356
# 699      356
# 700      356
# 701      356
# 702      356
# 703      356
# 704      356
# 705      356
# 706      356
# 707      356

# %%
#See 3 line graphs for different countries
# Relplot keeps the legend inside the graph
# sns.relplot(kind='line', data=temp_df, x='year', y='lifeExp',hue='country',style='continent')
sns.relplot(kind='line', data=temp_df, x='year', y='lifeExp', hue='country', style='continent', size='continent')

# %%
# lineplot keeps the legend inside the graph

sns.lineplot(data=temp_df, x='year', y='lifeExp', hue='country')
# Out:
# <Axes: xlabel='year', ylabel='lifeExp'>

# %%
# facet plot -> figure level function -> work with relplot
# it will not work with scatterplot and lineplot
# sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',hue='sex')
# sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',hue='sex',col='sex')
sns.relplot(data=tips, x='total_bill', y='tip', kind='scatter',hue='sex',col='sex',row='smoker')
# sns.relplot(data=tips, x='total_bill', y='tip', kind='line', col='sex', row='day')

# %%
# col wrap
# gap
# sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter')
# sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter', col='year')
sns.relplot(data=gap, x='lifeExp', y='gdpPercap', kind='scatter', col='year', col_wrap=3)

# %% [markdown]
# 2. Distribution Plots
#
#
# ->used for univariate analysis
#
# ->used to find out the distribution
#
# -> Range of the observation
#
# -> Central Tendency
#
# -> is the data bimodal?
#
# -> Are there outliers?
#
# => Plots under distribution plot
#
# -> histplot
#
# -> kdeplot
#
# -> rugplot

# %%
# figure level -> displot
# axes level -> histplot -> kdeplot -> rugplot

# %%
# plotting univariate histogram
sns.histplot(data=tips, x='total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.displot(data=tips, x='total_bill', kind='hist')

# %%
# bins parameter
tips
sns.displot(data=tips, x='total_bill', kind='hist',bins=2) #histogram is acting like a plot

# %%
# It’s also possible to visualize the distribution of a categorical variable using the logic of a histogram.
# Discrete bins are automatically set for categorical variables

# countplot
sns.displot(data=tips, x='day', kind='hist')
# tips

# %%
# hue parameter
sns.displot(data=tips, x='tip', kind='hist',hue='sex')

# %%
# element -> step -> only bars are visually created not wholly
sns.displot(data=tips, x='tip', kind='hist',hue='sex',element='step')

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# sns.displot(data=titanic, x='age', kind='hist',element='step')
sns.displot(data=titanic, x='age', kind='hist',element='step',hue='who')

# %%
# faceting using col and row -> not work on histplot function
sns.displot(data=tips, x='tip', kind='hist',col='sex',element='step')

# %%
# kdeplot - kerneldensityEstimation plot
# Rather than using discrete bins, a KDE plot smooths the observations with a Gaussian kernel, producing a continuous density estimate
# It creates a Gaussian kernal(curve)
tips
sns.kdeplot(data=tips,x='total_bill') #Y axis tells the density of probability.
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# convert from displot to kde
sns.displot(data=tips,x='total_bill',kind='kde')

# %%
# hue -> fill
# sns.displot(data=tips,x='total_bill',kind='kde',hue='sex')
sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True)
# sns.displot(data=tips,x='total_bill',kind='kde',hue='sex',fill=True,height=10,aspect=2)

# %%
# Rugplot

# Plot marginal distributions by drawing ticks along the x and y axes.

# This function is intended to complement other plots by showing the location of individual observations in an unobtrusive way.
sns.kdeplot(data=tips,x='total_bill')
sns.rugplot(data=tips,x='total_bill') # Yellow color data
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Bivariate histogram
# A bivariate histogram bins the data within rectangles that tile the plot
# and then shows the count of observations within each rectangle with the fill color

sns.histplot(data=tips, x='total_bill', y='tip')
# sns.displot(data=tips, x='total_bill', y='tip',kind='hist')

# %%
# Bivariate Kdeplot
# a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian
sns.kdeplot(data=tips, x='total_bill', y='tip')
# Lines are close so data is maximum there
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # **2. Matrix Plot**
#
# Heatmap
#
# Clustermap

# %%
gap
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# 3           4
# 4           4
# ...       ...
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716
#
# [1704 rows x 8 columns]

# %%
# Heatmap
#plotting every country life expectancy
# Plot rectangular data as a color-encoded matrix
temp_df = gap.pivot(index='country',columns='year',values='lifeExp')

# axes level function
# plt.figure(figsize=(10,10))
sns.heatmap(temp_df)
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# annot
temp_df = gap[gap['continent'] == 'Europe'].pivot(index='country',columns='year',values='lifeExp')

plt.figure(figsize=(15,15))
# sns.heatmap(temp_df,annot=True)
# linewidth for gap ,better for readibility +
sns.heatmap(temp_df,annot=True,linewidth=0.5, cmap='summer')
# Out:
# <Axes: xlabel='year', ylabel='country'>

# %%
# Clustermap

# Plot a matrix dataset as a hierarchically-clustered heatmap.

# This function requires scipy to be available.

iris = px.data.iris()
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      species_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 145           3
# 146           3
# 147           3
# 148           3
# 149           3
#
# [150 rows x 6 columns]

# %%
sns.clustermap(iris.iloc[:,[0,1,2,3]])
# columns misorganized
